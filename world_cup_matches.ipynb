# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
dataframe=pd.read_csv('/content/WorldCupMatches.csv')
dataframe
# Out:
#         Year              Datetime    Stage         Stadium         City  \
# 0     1930.0  13 Jul 1930 - 15:00   Group 1         Pocitos  Montevideo
# 1     1930.0  13 Jul 1930 - 15:00   Group 4  Parque Central  Montevideo
# 2     1930.0  14 Jul 1930 - 12:45   Group 2  Parque Central  Montevideo
# 3     1930.0  14 Jul 1930 - 14:50   Group 3         Pocitos  Montevideo
# 4     1930.0  15 Jul 1930 - 16:00   Group 1  Parque Central  Montevideo
# ...      ...                   ...      ...             ...          ...
# 4567     NaN                   NaN      NaN             NaN          NaN
# 4568     NaN                   NaN      NaN             NaN          NaN
# 4569     NaN                   NaN      NaN             NaN          NaN
# 4570     NaN                   NaN      NaN             NaN          NaN
# 4571     NaN                   NaN      NaN             NaN          NaN
#
#      Home Team Name  Home Team Goals  Away Team Goals Away Team Name  \
# ...

# %%
dataframe.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4572 entries, 0 to 4571
# Data columns (total 20 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   Year                  852 non-null    float64
#  1   Datetime              852 non-null    object
#  2   Stage                 852 non-null    object
#  3   Stadium               852 non-null    object
#  4   City                  852 non-null    object
#  5   Home Team Name        852 non-null    object
#  6   Home Team Goals       852 non-null    float64
#  7   Away Team Goals       852 non-null    float64
#  8   Away Team Name        852 non-null    object
#  9   Win conditions        852 non-null    object
#  10  Attendance            850 non-null    float64
#  11  Half-time Home Goals  852 non-null    float64
#  12  Half-time Away Goals  852 non-null    float64
#  13  Referee               852 non-null    object
# ...

# %%
dataframe.describe() #returns description of the data in the DataFrame.
# Out:
#               Year  Home Team Goals  Away Team Goals     Attendance  \
# count   852.000000       852.000000       852.000000     850.000000
# mean   1985.089202         1.811033         1.022300   45164.800000
# std      22.448825         1.610255         1.087573   23485.249247
# min    1930.000000         0.000000         0.000000    2000.000000
# 25%    1970.000000         1.000000         0.000000   30000.000000
# 50%    1990.000000         2.000000         1.000000   41579.500000
# 75%    2002.000000         3.000000         2.000000   61374.500000
# max    2014.000000        10.000000         7.000000  173850.000000
#
#        Half-time Home Goals  Half-time Away Goals       RoundID       MatchID
# count            852.000000            852.000000  8.520000e+02  8.520000e+02
# mean               0.708920              0.428404  1.066177e+07  6.134687e+07
# std                0.937414              0.691252  2.729613e+07  1.110572e+08
# ...

# %%
dataframe.shape #displays number of rows and columns
# Out:
# (4572, 20)

# %%
dataframe.columns #displays all the columns
# Out:
# Index(['Year', 'Datetime', 'Stage', 'Stadium', 'City', 'Home Team Name',
#        'Home Team Goals', 'Away Team Goals', 'Away Team Name',
#        'Win conditions', 'Attendance', 'Half-time Home Goals',
#        'Half-time Away Goals', 'Referee', 'Assistant 1', 'Assistant 2',
#        'RoundID', 'MatchID', 'Home Team Initials', 'Away Team Initials'],
#       dtype='object')

# %%
dataframe[1001:1005] #displays rows 1001 to 1004
# Out:
#       Year Datetime Stage Stadium City Home Team Name  Home Team Goals  \
# 1001   NaN      NaN   NaN     NaN  NaN            NaN              NaN
# 1002   NaN      NaN   NaN     NaN  NaN            NaN              NaN
# 1003   NaN      NaN   NaN     NaN  NaN            NaN              NaN
# 1004   NaN      NaN   NaN     NaN  NaN            NaN              NaN
#
#       Away Team Goals Away Team Name Win conditions  Attendance  \
# 1001              NaN            NaN            NaN         NaN
# 1002              NaN            NaN            NaN         NaN
# 1003              NaN            NaN            NaN         NaN
# 1004              NaN            NaN            NaN         NaN
#
#       Half-time Home Goals  Half-time Away Goals Referee Assistant 1  \
# 1001                   NaN                   NaN     NaN         NaN
# 1002                   NaN                   NaN     NaN         NaN
# 1003                   NaN                   NaN     NaN         NaN
# ...

# %%
dataframe['Away Team Goals'].max()
# Out:
# 7.0

# %%
dataframe['Home Team Goals'].min()
# Out:
# 0.0

# %%
dataframe['Attendance'].mean()
# Out:
# 45164.8

# %%
dataframe['MatchID'].median()
# Out:
# 2191.0

# %%
dataframe['Stadium'].mode()
# Out:
# 0    Estadio Azteca
# Name: Stadium, dtype: object

# %%
dataframe.isnull().sum()
# Out:
# Year                    3720
# Datetime                3720
# Stage                   3720
# Stadium                 3720
# City                    3720
# Home Team Name          3720
# Home Team Goals         3720
# Away Team Goals         3720
# Away Team Name          3720
# Win conditions          3720
# Attendance              3722
# Half-time Home Goals    3720
# Half-time Away Goals    3720
# Referee                 3720
# Assistant 1             3720
# Assistant 2             3720
# RoundID                 3720
# MatchID                 3720
# Home Team Initials      3720
# Away Team Initials      3720
# dtype: int64

# %%
x=dataframe['Attendance'].mean()
dataframe['Attendance'].fillna(x,inplace=True) #replaces missing values with mean value

# %%
z=dataframe['Away Team Goals'].median()
dataframe['Away Team Goals'].fillna(z,inplace=True) #replaces missing values with median value

# %%
y=dataframe['Stadium'].mode()
dataframe['Stadium'].fillna(y,inplace=True) #replaces missing values with mode value

# %%
a=dataframe['Home Team Goals']
plt.plot(a,label='Home Team Goals')
plt.xlabel('Home Team Goals')
plt.legend()
plt.show()

# %%
sns.pairplot(dataframe)

# %%
sns.barplot(x='Home Team Goals',y='Away Team Goals',data=dataframe)
# Out:
# <Axes: xlabel='Home Team Goals', ylabel='Away Team Goals'>

# %%
sns.histplot(dataframe['Attendance'])
# Out:
# <Axes: xlabel='Attendance', ylabel='Count'>

# %%
sns.distplot(dataframe['Half-time Home Goals'])
# Out:
# <ipython-input-24-ee0d8e15c305>:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(dataframe['Half-time Home Goals'])
# <Axes: xlabel='Half-time Home Goals', ylabel='Density'>

# %%
sns.boxplot(dataframe['Home Team Goals'])
# Out:
# <Axes: ylabel='Home Team Goals'>

# %%
sns.scatterplot(x='Half-time Home Goals',y='MatchID',data=dataframe)
# Out:
# <Axes: xlabel='Half-time Home Goals', ylabel='MatchID'>

# %%
a=dataframe['Home Team Goals']
b=dataframe['Away Team Goals']
sns.heatmap(pd.crosstab(a,b),annot=True)
# Out:
# <Axes: xlabel='Away Team Goals', ylabel='Home Team Goals'>
